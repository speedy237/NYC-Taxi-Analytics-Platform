# %%
print("Table Weather Impact")
weather=spark.table("iceberg.gold.weather_impact")
weather.printSchema()
weather.limit(5).toPandas()
# Out:
# Table Weather Impact
# root
#  |-- pickup_date: date (nullable = true)
#  |-- tpep_pickup_datetime: timestamp_ntz (nullable = true)
#  |-- is_rainy: boolean (nullable = true)
#  |-- is_cold: boolean (nullable = true)
#  |-- total_trips: long (nullable = true)
#  |-- avg_distance: double (nullable = true)
#  |-- avg_duration: double (nullable = true)
#  |-- avg_fare: double (nullable = true)
#  |-- avg_speed: double (nullable = true)
#  |-- avg_tip_pct: double (nullable = true)
#  |-- avg_temp: double (nullable = true)
#  |-- avg_rhum: double (nullable = true)
#  |-- avg_prcp: double (nullable = true)
#  |-- avg_wspd: double (nullable = true)
#  |-- avg_pres: double (nullable = true)
#  |-- weather_condition: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
# ...

# %%
print("Table Drivers Performance")
drivers=spark.table("iceberg.gold.driver_performance")
drivers.printSchema()
drivers.limit(5).toPandas()
# Out:
# Table Drivers Performance
# root
#  |-- VendorID: integer (nullable = true)
#  |-- pickup_date: date (nullable = true)
#  |-- trips_completed: long (nullable = true)
#  |-- total_revenue: double (nullable = true)
#  |-- avg_trip_duration: double (nullable = true)
#  |-- avg_fare: double (nullable = true)
#  |-- avg_speed: double (nullable = true)
#  |-- total_tips: double (nullable = true)
#  |-- avg_tip_percentage: double (nullable = true)
#  |-- credit_card_trips: long (nullable = true)
#  |-- cash_trips: long (nullable = true)
#  |-- revenue_per_hour: double (nullable = true)
#  |-- credit_card_percentage: double (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#    VendorID pickup_date  trips_completed  total_revenue  avg_trip_duration   avg_fare  avg_speed  total_tips  avg_tip_percentage  credit_card_trips  cash_trips  revenue_per_hour  \
# ...

# %%
print("hourly Pattern")
hourly=spark.table("iceberg.gold.hourly_patterns")
hourly.printSchema()
hourly.limit(5).toPandas()
# Out:
# hourly Pattern
# root
#  |-- pickup_date: date (nullable = true)
#  |-- pickup_hour: integer (nullable = true)
#  |-- trip_count: long (nullable = true)
#  |-- avg_distance: double (nullable = true)
#  |-- avg_duration: double (nullable = true)
#  |-- avg_fare: double (nullable = true)
#  |-- avg_speed: double (nullable = true)
#  |-- avg_tip_pct: double (nullable = true)
#  |-- weekend_trips: long (nullable = true)
#  |-- weekday_trips: long (nullable = true)
#  |-- hour_type: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#   pickup_date  pickup_hour  trip_count  avg_distance  avg_duration   avg_fare  avg_speed  avg_tip_pct  weekend_trips  weekday_trips      hour_type  year  month
# 0  2024-04-07           12        5358      3.504188     14.894609  27.463899  11.987319    12.275662           5358              0  regular_hours  2024      4
# ...

# %%
print("Print Top Routes")
routes=spark.table("iceberg.gold.top_routes")
routes.printSchema()
routes.limit(5).toPandas()
# Out:
# Print Top Routes
# root
#  |-- route_id: string (nullable = true)
#  |-- PULocationID: integer (nullable = true)
#  |-- DOLocationID: integer (nullable = true)
#  |-- pickup_date: date (nullable = true)
#  |-- trip_count: long (nullable = true)
#  |-- avg_distance: double (nullable = true)
#  |-- avg_duration: double (nullable = true)
#  |-- avg_fare: double (nullable = true)
#  |-- avg_speed: double (nullable = true)
#  |-- avg_tip_pct: double (nullable = true)
#  |-- total_passengers: long (nullable = true)
#  |-- efficiency_ratio: double (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#   route_id  PULocationID  DOLocationID pickup_date  trip_count  avg_distance  avg_duration   avg_fare  avg_speed  avg_tip_pct  total_passengers  efficiency_ratio  year  month
# 0  237_236           237           236  2024-04-17         998      1.070651      7.887325  16.355782   8.931578    13.468188              1272          0.135743  2024      4
# ...

# %%
print("Payment Analysis")
payment=spark.table("iceberg.gold.payment_analysis")
payment.printSchema()
payment.limit(5).toPandas()
# Out:
# Payment Analysis
# root
#  |-- pickup_date: date (nullable = true)
#  |-- payment_type: long (nullable = true)
#  |-- trip_count: long (nullable = true)
#  |-- total_revenue: double (nullable = true)
#  |-- avg_fare: double (nullable = true)
#  |-- total_tips: double (nullable = true)
#  |-- avg_tip_pct: double (nullable = true)
#  |-- avg_distance: double (nullable = true)
#  |-- payment_type_label: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#   pickup_date  payment_type  trip_count  total_revenue   avg_fare  total_tips  avg_tip_pct  avg_distance payment_type_label  year  month
# 0  2024-04-05             1       90301     2615057.17  28.959338   382584.38    14.541913      3.306086        credit_card  2024      4
# 1  2024-04-06             1       85948     2322171.50  27.018331   342322.07    14.629913      3.080849        credit_card  2024      4
# ...
